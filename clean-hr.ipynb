# %%
import pandas as pd
from datetime import datetime

# %%
employee_survey_data = pd.read_csv('data/employee_survey_data.csv')
general_data = pd.read_csv('data/general_data.csv')
in_time = pd.read_csv('data/in_time.csv')
manager_survey_data = pd.read_csv('data/manager_survey_data.csv')
out_time = pd.read_csv('data/out_time.csv')

# %%
employee_survey_data.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
#checking if employeeID is unique
len(employee_survey_data.EmployeeID.unique())== employee_survey_data.shape[0]
# Out:
# True

# %%
general_data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
#full join
general_data.merge(employee_survey_data,left_on='EmployeeID',right_on='EmployeeID').head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    StandardHours StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
#inner join
new_general_data = general_data.merge(employee_survey_data,left_on='EmployeeID',right_on='EmployeeID',how='inner')

# %%
all_data = new_general_data.merge(manager_survey_data,
                                  left_on='EmployeeID',
                                  right_on='EmployeeID')

# %%
in_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06  ...
# ...

# %%
out_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58  ...
# ...

# %%
a = in_time[in_time['Unnamed: 0']==1]['2015-01-02'].values[0]
b = out_time[out_time['Unnamed: 0']==1]['2015-01-02'].values[0]

# %%
a.pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [47], line 1
# ----> 1 a.pd
#
# AttributeError: 'str' object has no attribute 'pd'

# %%
# c = a.pd.to_datetime - b.pd.to_datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [46], line 1
# ----> 1 c = a.pd.to_datetime - b.pd.to_datetime
#
# AttributeError: 'str' object has no attribute 'pd'

# %%
# a = in_time['2015-01-02'].str.split('/').str[0].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [50], line 1
# ----> 1 a = in_time['2015-01-02'].str.split('/').str[0].astype('int32')
#
# File ~/Documents/data science/Hr-Data-Analytics/venv/lib64/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
a
